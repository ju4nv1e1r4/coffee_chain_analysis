# %%
import pandas as pd
import numpy as np
import re

df = pd.read_csv(
    r'C:\Users\JUAN\Desktop\.begin\tudo\vscode\projects_files\etl\coffee chain\Coffee Chain.csv')
# https://www.kaggle.com/datasets/edmund24/coffee-chain

# %%
df.head(5)
# Out:
#    Area Code  Cogs  Difference Between Actual and Target Profit  \
# 0        303    51                                          -35
# 1        970    52                                          -24
# 2        409    43                                          -22
# 3        850    38                                          -15
# 4        562    72                                            6
#
#                       Date  Inventory  Margin     Market Size     Market  \
# 0  2012-10-01 00:00:00.000        503      71  "Major Market"  "Central"
# 1  2012-10-01 00:00:00.000        405      71  "Major Market"  "Central"
# 2  2012-10-01 00:00:00.000        419      64  "Major Market"    "South"
# 3  2012-10-01 00:00:00.000        871      56  "Major Market"     "East"
# 4  2012-10-01 00:00:00.000        650     110  "Major Market"     "West"
#
#    Marketing  记录数  ...       Product Profit Sales         State  Target COGS  \
# ...

# %%
df.shape
# Out:
# (1062, 22)

# %%
df.columns
# Out:
# Index(['Area Code', 'Cogs', 'Difference Between Actual and Target Profit',
#        'Date', 'Inventory', 'Margin', 'Market Size', 'Market', 'Marketing',
#        '记录数', 'Product Line', 'Product Type', 'Product', 'Profit', 'Sales',
#        'State', 'Target COGS', 'Target Margin', 'Target Profit',
#        'Target Sales', 'Total Expenses', 'Type'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Area Code                                       int64
# Cogs                                            int64
# Difference Between Actual and Target Profit     int64
# Date                                           object
# Inventory                                       int64
# Margin                                          int64
# Market Size                                    object
# Market                                         object
# Marketing                                       int64
# 记录数                                             int64
# Product Line                                   object
# Product Type                                   object
# Product                                        object
# Profit                                          int64
# Sales                                           int64
# State                                          object
# Target COGS                                     int64
# ...

# %%
nulls = df.isnull().sum()
nulls
# Out:
# Area Code                                      0
# Cogs                                           0
# Difference Between Actual and Target Profit    0
# Date                                           0
# Inventory                                      0
# Margin                                         0
# Market Size                                    0
# Market                                         0
# Marketing                                      0
# 记录数                                            0
# Product Line                                   0
# Product Type                                   0
# Product                                        0
# Profit                                         0
# Sales                                          0
# State                                          0
# Target COGS                                    0
# Target Margin                                  0
# Target Profit                                  0
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Area Code                                               int64
# Cogs                                                    int64
# Difference Between Actual and Target Profit             int64
# Date                                           datetime64[ns]
# Inventory                                               int64
# Margin                                                  int64
# Market Size                                            object
# Market                                                 object
# Marketing                                               int64
# 记录数                                                     int64
# Product Line                                           object
# Product Type                                           object
# Product                                                object
# Profit                                                  int64
# Sales                                                   int64
# ...

# %%
def _replace_(x):
    return x.replace('"', '', regex=True)

# %%
df = _replace_(df)
df.head(5)
# Out:
#    Area Code  Cogs  Difference Between Actual and Target Profit       Date  \
# 0        303    51                                          -35 2012-10-01
# 1        970    52                                          -24 2012-10-01
# 2        409    43                                          -22 2012-10-01
# 3        850    38                                          -15 2012-10-01
# 4        562    72                                            6 2012-10-01
#
#    Inventory  Margin   Market Size   Market  Marketing  记录数  ...     Product  \
# 0        503      71  Major Market  Central         46    1  ...       Lemon
# 1        405      71  Major Market  Central         17    1  ...        Mint
# 2        419      64  Major Market    South         13    1  ...       Lemon
# 3        871      56  Major Market     East         10    1  ...  Darjeeling
# 4        650     110  Major Market     West         23    1  ...   Green Tea
#
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Cogs', 'Difference Between Actual and Target Profit',
#        'Date', 'Inventory', 'Margin', 'Market Size', 'Market', 'Marketing',
#        '记录数', 'Product Line', 'Product Type', 'Product', 'Profit', 'Sales',
#        'State', 'Target COGS', 'Target Margin', 'Target Profit',
#        'Target Sales', 'Total Expenses', 'Type'],
#       dtype='object')

# %%
columns_to_rename = {'Cogs':'COGS','Difference Between Actual and Target Profit':'Profit GAP',
                     'Margin':'Profit Margin','Market':'Segment','记录数':'Entries',
                     'Sales':'Revenue','Target Margin':'Target Profit Margin','Target Sales':'Target Revenue'}

df = df.rename(columns=(columns_to_rename))
df.columns
# Out:
# Index(['Area Code', 'COGS', 'Profit GAP', 'Date', 'Inventory', 'Profit Margin',
#        'Market Size', 'Segment', 'Marketing', 'Entries', 'Product Line',
#        'Product Type', 'Product', 'Profit', 'Revenue', 'State', 'Target COGS',
#        'Target Profit Margin', 'Target Profit', 'Target Revenue',
#        'Total Expenses', 'Type'],
#       dtype='object')

# %%
df['Profit GAP'] = df['Profit GAP'] /100
df['Profit Margin'] = df['Profit Margin'] /100
df['Target Profit Margin'] = df['Target Profit Margin'] /100

df
# Out:
#       Area Code  COGS  Profit GAP       Date  Inventory  Profit Margin  \
# 0           303    51       -0.35 2012-10-01        503           0.71
# 1           970    52       -0.24 2012-10-01        405           0.71
# 2           409    43       -0.22 2012-10-01        419           0.64
# 3           850    38       -0.15 2012-10-01        871           0.56
# 4           562    72        0.06 2012-10-01        650           1.10
# ...         ...   ...         ...        ...        ...            ...
# 1057        775   250        1.33 2013-12-01       1820           2.51
# 1058        971    88        0.48 2013-12-01        817           1.33
# 1059        775   294       -2.85 2013-12-01       8252          -2.94
# 1060        503   134        0.80 2013-12-01        690           1.86
# 1061        435    20       -0.22 2013-12-01        218           0.25
#
#        Market Size  Segment  Marketing  Entries  ...     Product Profit  \
# ...

# %%
df.dtypes
# Out:
# Area Code                        int64
# COGS                             int64
# Profit GAP                     float64
# Date                    datetime64[ns]
# Inventory                        int64
# Profit Margin                  float64
# Market Size                     object
# Segment                         object
# Marketing                        int64
# Entries                          int64
# Product Line                    object
# Product Type                    object
# Product                         object
# Profit                           int64
# Revenue                          int64
# State                           object
# Target COGS                      int64
# Target Profit Margin           float64
# Target Profit                    int64
# Target Revenue                   int64
# Total Expenses                   int64
# Type                            object
# dtype: object

# %%
df.to_csv('../../data/coffeechain_cleaned.csv')
